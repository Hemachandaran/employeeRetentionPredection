# %%
import streamlit as st
import joblib  # Use joblib for loading LightGBM models
import pickle
from preprocessing_1 import Preprocessing
import torch
import torch.nn as nn
import pandas as pd

# Load the LightGBM model using joblib
try:
    lightgbm_model = joblib.load('lightgbm_model.pkl')
except Exception as e:
    st.error("Error loading LightGBM model: " + str(e))

# Load the pickled text model and vectorizer
try:
    with open('text_model.pkl', 'rb') as model_file:
        model_weights = pickle.load(model_file)

    with open('vectorizer_text.pkl', 'rb') as vectorizer_file:
        loaded_vectorizer = pickle.load(vectorizer_file)
except Exception as e:
    st.error("Error loading text model or vectorizer: " + str(e))

def encode_input_data(input_data):
    df = pd.DataFrame(input_data, columns=[
        'enrollee_id', 'city', 'city_development_index', 'gender',
        'relevent_experience', 'enrolled_university', 'education_level',
        'major_discipline', 'experience', 'company_size',
        'company_type', 'last_new_job', 'training_hours'
    ])

    pr = Preprocessing(df)
    in_df = pr.handle_nulls()
    in_df = pr.encode_features()
    
    # One-hot encode categorical variables
    df_encoded = pd.get_dummies(in_df)
    
    return df_encoded.values

# Define the neural network class
class SimpleNN(nn.Module):
    def __init__(self, input_dim):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.dropout1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(128, 64)
        self.dropout2 = nn.Dropout(0.5)
        self.fc3 = nn.Linear(64, 2)  # Output layer for binary classification

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.dropout1(x)
        x = torch.relu(self.fc2(x))
        x = self.dropout2(x)
        x = self.fc3(x)
        return x

# Initialize the neural network model
input_dim = 472  # Adjust this based on your TF-IDF features
model = SimpleNN(input_dim=input_dim)
model.load_state_dict(model_weights)
model.eval()

# Function for automatic classification
def automatic_classification(input_text):
    features_tfidf = loaded_vectorizer.transform([input_text]).toarray()
    features_tensor = torch.FloatTensor(features_tfidf)

    with torch.no_grad():
        output = model(features_tensor)
        _, predicted_class = torch.max(output.data, 1)

    return predicted_class.item()

# Function for manual classification using LightGBM
def manual_classification(features):
    # features_df = pd.DataFrame([features])
    encode_df = encode_input_data(features)
    prediction = lightgbm_model.predict(encode_df)
    return prediction

# Streamlit app layout
st.title("Classification App")

classification_type = st.selectbox("Choose classification type:", ["Automatic", "Manual"])

if classification_type == "Automatic":
    input_text = st.text_area("Enter text for classification:")
    
    if st.button("Classify"):
        if input_text:
            result = automatic_classification(input_text)
            st.success(f"Prediction: {result}")
        else:
            st.error("Please enter some text to classify.")

elif classification_type == "Manual":
    # Get user inputs for each feature
    enrollee_id = st.text_input("Enrollee ID:")
    
    city = st.selectbox("City:", ['city_103', 'city_40', 'city_21', 'city_115', 'city_162',
                                   'city_176', 'city_160', 'city_46', 'city_61', 'city_114',
                                   'city_13', 'city_159', 'city_102', 'city_67', 'city_100',
                                   'city_16', 'city_71', 'city_104', 'city_64', 'city_101',
                                   'city_83', 'city_105', 'city_73', 'city_75', 'city_41',
                                   'city_11', 'city_93', 'city_90', 'city_36', 'city_20',
                                   'city_57', 'city_152', 'city_19', 'city_65', 'city_74',
                                   'city_173', 'city_136', 'city_98', 'city_97', 'city_50',
                                   'city_138', 'city_82', 'city_157', 'city_89'])
    
    gender = st.selectbox("Gender:", ['Male', 'Not_specified', 'Female', 'Other'])
    
    relevant_experience = st.selectbox("Relevant Experience:", ['Has relevant experience',
                                                                'No relevant experience'])
    
    enrolled_university = st.selectbox("Enrolled University:", ['no_enrollment',
                                                                'Full time course',
                                                                'none',
                                                                'Part time course'])
    
    education_level = st.selectbox("Education Level:", ['Graduate',
                                                         'Masters',
                                                         'High School',
                                                         'Other',
                                                         'Phd',
                                                         'Primary School'])
    
    major_discipline = st.selectbox("Major Discipline:", ['STEM',
                                                           'Business Degree',
                                                           'Not_Specified',
                                                           'Arts',
                                                           'Humanities',
                                                           'No Major',
                                                           'Other'])
    
    experience = st.selectbox("Experience:", ['>20','15','5','<1','11','13','7','17','2','16','1','4','10','14','18','19','12','3','6','9','8','20'])
    
    company_size = st.selectbox("Company Size:", ['NS','50-99','<10','10000+','5000-9999',
                                                   '1000-4999','10/49','100-500','500-999'])
    
    company_type = st.selectbox("Company Type:", ['not_specified','Pvt Ltd','Funded Startup',
                                                   'Early Stage Startup','Other',
                                                   'Public Sector','NGO'])
    
    last_new_job = st.selectbox("Last New Job:", ['1','>4','never','4','3','2','Not Specified'])

    training_hours = st.number_input("Training Hours", min_value=0)

    if st.button("Classify"):
        # Prepare features dictionary including all required fields
        features = {
            "Enrollee ID": enrollee_id,
            "City": city,
            "Gender": gender,
            "Relevant Experience": relevant_experience,
            "Enrolled University": enrolled_university,
            "Education Level": education_level,
            "Major Discipline": major_discipline,
            "Experience": experience,
            "Company Size": company_size,
            "Company Type": company_type,
            "Last New Job": last_new_job,
            "Training Hours": training_hours
        }
        
        # Check if all required fields are filled before classifying
        if any(value == "" for value in features.values()):
            st.error("Please fill in all fields.")
        else:
            result = manual_classification(features)
            st.success(f"Prediction: {result[0]}")

# %% [markdown]
# # creating pipeline and colum transformers

# %%
import pandas as pd
import numpy as np
from lightgbm import LGBMClassifier
from imblearn.over_sampling import SMOTENC
from pre_processing import Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class CustomPreprocessor(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.preprocessing = Preprocessing(df=None)  # Placeholder for DataFrame

    def fit(self, X, y=None):
        return self  # Nothing to fit

    def transform(self, X):
        self.preprocessing.df = X.copy()  # Set the DataFrame for preprocessing
        return self.preprocessing.preprocess(X)  # Call your preprocess method

# %%
# Load your dataset
df = pd.read_csv("aug_train.csv")

# Split the data into features and target variable
X = df.drop("target", axis=1)
y = "target"

# Create the custom preprocessor instance
custom_preprocessor = CustomPreprocessor()

# Define the pipeline
pipeline = Pipeline(steps=[
    ('preprocessor', custom_preprocessor),
    ('model', LGBMClassifier(num_leaves=66, learning_rate=0.09219174413525645, n_estimators=183))
])

# Fit the pipeline on the training data
pipeline.fit(X, y)
# Out:
# Encoding features...
# data created
# inside the target mean feature else
# city
#
# inside the if: city
#
# inside the zip loop city_1->0.11538461538461539
#
# inside the zip loop city_10->0.10465116279069768
#
# inside the zip loop city_100->0.23636363636363636
#
# inside the zip loop city_101->0.5733333333333334
#
# inside the zip loop city_102->0.17105263157894737
#
# inside the zip loop city_103->0.21308840413318025
#
# city_development_index
#
# gender
#
# inside the if: gender
#
# inside the zip loop Female->0.2633279483037157
#
# inside the zip loop Male->0.22781937826185614
#
# relevent_experience
#
# inside the if: relevent_experience
#
# inside the zip loop Has relevent experience->1
#
# enrolled_university
#
# inside the if: enrolled_university
#
# inside the zip loop Full time course->0.380889007186585
#
# inside the zip loop Part time course->0.25208681135225375
#
# inside the zip loop no_enrollment->0.21140623869146705
#
# education_level
#
# inside the if: education_level
#
# inside the zip loop Graduate->0.2797896188998103
#
# major_discipline
#
# inside the if: major_discipline
#
# inside the zip loop Arts->0.20948616600790515
#
# inside the zip loop Business Degree->0.26299694189602446
#
# inside the zip loop Humanities->0.21076233183856502
#
# inside the zip loop No Major->0.24663677130044842
#
# inside the zip loop Not_Specified->0.19516530394596515
#
# inside the zip loop Other->0.2677165354330709
#
# inside the zip loop STEM->0.2615926028153464
#
# experience
#
# inside the if: experience
#
# inside the zip loop <1->0
#
# inside the zip loop 1->1
#
# inside the zip loop 2->2
#
# inside the zip loop 3->3
#
# inside the zip loop 4->4
#
# inside the zip loop 5->5
#
# inside the zip loop 6->6
#
# inside the zip loop 7->7
#
# inside the zip loop 8->8
#
# inside the zip loop 9->9
#
# inside the zip loop 10->10
#
# inside the zip loop 11->11
#
# inside the zip loop 12->12
#
# inside the zip loop 13->13
#
# inside the zip loop 14->14
#
# inside the zip loop 15->15
#
# inside the zip loop 16->16
#
# inside the zip loop 17->17
#
# inside the zip loop 18->18
#
# inside the zip loop 19->19
#
# inside the zip loop 20->20
#
# inside the zip loop >20->21
#
# company_size
#
# inside the if: company_size
#
# inside the zip loop NS->1
#
# company_type
#
# inside the if: company_type
#
# inside the zip loop Early Stage Startup->0.23548922056384744
#
# inside the zip loop Funded Startup->0.13986013986013987
#
# inside the zip loop NGO->0.18618042226487524
#
# inside the zip loop Other->0.2396694214876033
#
# inside the zip loop Public Sector->0.2198952879581152
#
# inside the zip loop Pvt Ltd->0.18080880105938676
#
# inside the zip loop not_specified->0.38827361563517915
#
# last_new_job
#
# inside the if: last_new_job
#
# inside the zip loop 1->2
#
# Handling outliers...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 18
#      12 pipeline = Pipeline(steps=[
#      13     ('preprocessor', custom_preprocessor),
#      14     ('model', LGBMClassifier(num_leaves=66, learning_rate=0.09219174413525645, n_estimators=183))
#      15 ])
#      17 # Fit the pipeline on the training data
# ---> 18 pipeline.fit(X, y)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:469, in Pipeline.fit(self, X, y, **params)
#     426 """Fit the model.
#     427
#     428 Fit all the transformers one after the other and sequentially transform the
#    (...)
#     466     Pipeline with fitted steps.
#     467 """
#     468 routed_params = self._check_method_params(method="fit", props=params)
# --> 469 Xt = self._fit(X, y, routed_params)
#     470 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     471     if self._final_estimator != "passthrough":
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:406, in Pipeline._fit(self, X, y, routed_params)
#     404     cloned_transformer = clone(transformer)
#     405 # Fit or load from cache the current transformer
# --> 406 X, fitted_transformer = fit_transform_one_cached(
#     407     cloned_transformer,
#     408     X,
#     409     y,
#     410     None,
#     411     message_clsname="Pipeline",
#     412     message=self._log_message(step_idx),
#     413     params=routed_params[name],
#     414 )
#     415 # Replace the transformer of the step with the fitted
#     416 # transformer. This is necessary when loading the transformer
#     417 # from the cache.
#     418 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/.local/lib/python3.12/site-packages/joblib/memory.py:312, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     311 def __call__(self, *args, **kwargs):
# --> 312     return self.func(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/pipeline.py:1310, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1308 with _print_elapsed_time(message_clsname, message):
#    1309     if hasattr(transformer, "fit_transform"):
# -> 1310         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1311     else:
#    1312         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1313             X, **params.get("transform", {})
#    1314         )
#
# File ~/.local/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/.local/lib/python3.12/site-packages/sklearn/base.py:1101, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
# -> 1101     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# Cell In[8], line 10, in CustomPreprocessor.transform(self, X)
#       8 def transform(self, X):
#       9     self.preprocessing.df = X.copy()  # Set the DataFrame for preprocessing
# ---> 10     return self.preprocessing.preprocess(X)
#
# File /workspaces/employeeRetentionPredection/pre_processing.py:216, in Preprocessing.preprocess(self, df)
#     214  # Handle outliers and skewness after encoding
#     215 print("Handling outliers...")
# --> 216 self.handle_outliers(df,['training_hours',
#     217                                             'last_new_job',
#     218                                             'city_development_index'])
#     220 print("Handling skewness...")
#     221 self.handle_skewness(df,['training_hours',
#     222                                             'last_new_job',
#     223                                             'city_development_index'])
#
# File /workspaces/employeeRetentionPredection/pre_processing.py:139, in Preprocessing.handle_outliers(self, df, features)
#     137 """Handle outliers by capping them for specified features."""
#     138 for feature in features:
# --> 139     Q1 = df[feature].quantile(0.25)
#     140     Q3 = df[feature].quantile(0.75)
#     141     IQR = Q3 - Q1
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/series.py:2887, in Series.quantile(self, q, interpolation)
#    2883 # We dispatch to DataFrame so that core.internals only has to worry
#    2884 #  about 2D cases.
#    2885 df = self.to_frame()
# -> 2887 result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2888 if result.ndim == 2:
#    2889     result = result.iloc[:, 0]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:12146, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12140 axis = self._get_axis_number(axis)
#   12142 if not is_list_like(q):
#   12143     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   12144     # error: List item 0 has incompatible type "float | ExtensionArray |
#   12145     # ndarray[Any, Any] | Index | Series | Sequence[float]"; expected "float"
# > 12146     res_df = self.quantile(
#   12147         [q],  # type: ignore[list-item]
#   12148         axis=axis,
#   12149         numeric_only=numeric_only,
#   12150         interpolation=interpolation,
#   12151         method=method,
#   12152     )
#   12153     if method == "single":
#   12154         res = res_df.iloc[0]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:12191, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12187     raise ValueError(
#   12188         f"Invalid method: {method}. Method must be in {valid_method}."
#   12189     )
#   12190 if method == "single":
# > 12191     res = data._mgr.quantile(qs=q, interpolation=interpolation)
#   12192 elif method == "table":
#   12193     valid_interpolation = {"nearest", "lower", "higher"}
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/internals/managers.py:1549, in BlockManager.quantile(self, qs, interpolation)
#    1545 new_axes = list(self.axes)
#    1546 new_axes[1] = Index(qs, dtype=np.float64)
#    1548 blocks = [
# -> 1549     blk.quantile(qs=qs, interpolation=interpolation) for blk in self.blocks
#    1550 ]
#    1552 return type(self)(blocks, new_axes)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/internals/blocks.py:1891, in Block.quantile(self, qs, interpolation)
#    1888 assert self.ndim == 2
#    1889 assert is_list_like(qs)  # caller is responsible for this
# -> 1891 result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1892 # ensure_block_shape needed for cases where we start with EA and result
#    1893 #  is ndarray, e.g. IntegerArray, SparseArray
#    1894 result = ensure_block_shape(result, ndim=2)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/array_algos/quantile.py:39, in quantile_compat(values, qs, interpolation)
#      37     fill_value = na_value_for_dtype(values.dtype, compat=False)
#      38     mask = isna(values)
# ---> 39     return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      40 else:
#      41     return values._quantile(qs, interpolation)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/array_algos/quantile.py:97, in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      95     result = np.repeat(flat, len(values)).reshape(len(values), len(qs))
#      96 else:
# ---> 97     result = _nanpercentile(
#      98         values,
#      99         qs * 100.0,
#     100         na_value=fill_value,
#     101         mask=mask,
#     102         interpolation=interpolation,
#     103     )
#     105     result = np.asarray(result)
#     106     result = result.T
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/array_algos/quantile.py:218, in _nanpercentile(values, qs, na_value, mask, interpolation)
#     216     return result
#     217 else:
# --> 218     return np.percentile(
#     219         values,
#     220         qs,
#     221         axis=1,
#     222         # error: No overload variant of "percentile" matches argument types
#     223         # "ndarray[Any, Any]", "ndarray[Any, dtype[floating[_64Bit]]]",
#     224         # "int", "Dict[str, str]"  [call-overload]
#     225         method=interpolation,  # type: ignore[call-overload]
#     226     )
#
# File ~/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:4238, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4235     if np.any(weights < 0):
#    4236         raise ValueError("Weights must be non-negative.")
# -> 4238 return _quantile_unchecked(
#    4239     a, q, axis, out, overwrite_input, method, keepdims, weights)
#
# File ~/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:4517, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4508 def _quantile_unchecked(a,
#    4509                         q,
#    4510                         axis=None,
#    (...)
#    4514                         keepdims=False,
#    4515                         weights=None):
#    4516     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4517     return _ureduce(a,
#    4518                     func=_quantile_ureduce_func,
#    4519                     q=q,
#    4520                     weights=weights,
#    4521                     keepdims=keepdims,
#    4522                     axis=axis,
#    4523                     out=out,
#    4524                     overwrite_input=overwrite_input,
#    4525                     method=method)
#
# File ~/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3848, in _ureduce(a, func, keepdims, **kwargs)
#    3845             index_out = (0, ) * nd
#    3846             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3848 r = func(a, **kwargs)
#    3850 if out is not None:
#    3851     return out
#
# File ~/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:4694, in _quantile_ureduce_func(a, q, weights, axis, out, overwrite_input, method)
#    4692         arr = a.copy()
#    4693         wgt = weights
# -> 4694 result = _quantile(arr,
#    4695                    quantiles=q,
#    4696                    axis=axis,
#    4697                    method=method,
#    4698                    out=out,
#    4699                    weights=wgt)
#    4700 return result
#
# File ~/.local/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:4809, in _quantile(arr, quantiles, axis, method, out, weights)
#    4805 previous_indexes, next_indexes = _get_indexes(arr,
#    4806                                               virtual_indexes,
#    4807                                               values_count)
#    4808 # --- Sorting
# -> 4809 arr.partition(
#    4810     np.unique(np.concatenate(([0, -1],
#    4811                               previous_indexes.ravel(),
#    4812                               next_indexes.ravel(),
#    4813                               ))),
#    4814     axis=0)
#    4815 if supports_nans:
#    4816     slices_having_nans = np.isnan(arr[-1, ...])
#
# TypeError: '<' not supported between instances of 'str' and 'int'
